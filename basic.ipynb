# %%
import cv2
import matplotlib.pyplot as plt

# %%
#read image
img=cv2.imread("dog.jpg")
print(img)
# Out:
# [[[123 188 166]
#   [123 188 166]
#   [123 188 166]
#   ...
#   [115 182 161]
#   [115 182 161]
#   [115 182 161]]
#
#  [[123 188 166]
#   [123 188 166]
#   [123 188 166]
#   ...
#   [116 183 162]
#   [116 183 162]
#   [116 183 162]]
#
#  [[123 188 166]
#   [123 188 166]
#   [123 188 166]
#   ...
#   [116 183 162]
#   [116 183 162]
#   [116 183 162]]
#
#  ...
#
#  [[ 54 122  99]
#   [ 54 122  99]
#   [ 54 122  99]
#   ...
#   [ 72 126 121]
#   [ 72 126 121]
#   [ 72 126 121]]
#
#  [[ 54 122  99]
#   [ 54 122  99]
#   [ 54 122  99]
#   ...
#   [ 72 126 121]
#   [ 72 126 121]
#   [ 72 126 121]]
#
#  [[ 52 122  99]
#   [ 52 122  99]
#   [ 51 121  98]
#   ...
#   [ 75 127 120]
#   [ 75 127 120]
#   [ 74 126 119]]]

# %%
print(img.shape)
# Out:
# (1197, 1200, 3)

# %%
plt.imshow(img)

# %%
#convert color
newimg=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(newimg)
plt.axis("off")
# Out:
# (-0.5, 1199.5, 1196.5, -0.5)
